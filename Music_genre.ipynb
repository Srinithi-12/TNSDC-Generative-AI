# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <center>“<b>The most exciting rhythms seem unexpected and complex, the most beautiful melodies simple and inevitable.</b>”<br><t>― W.H. Auden, The Complete Works of W.H. Auden: Prose, Volume III, 1949-1955</center>

# %%
# music genre Classification
# Goal of this project is to apply the concepts learned in CNN( / convolutional Neural Network)
# here I m using GTZAN dataset

# %% [markdown]
# We have genres :
# * Rock
# * Clasical
# * Disco
# * Hip-Hop
# * Jazz
# * Blues
# * Metal
# * Pop
# * Country
# * Reggae (hearing this first time :P)
#
# Total 10

# %%
# lets import libraries that we will be usings
# we already have imported pandas and numpy

import matplotlib.pyplot as plt
import scipy
import librosa
import librosa.display
import IPython.display as ipd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow import keras
import pickle # model pickling for future use

# %% [markdown]
# # Loading Datasets

# %%
# Loading dataset
# we have 2 CSVs here, one containing features for 30 sec audio file, mean & variance for diff features we have, then
# and one for 3 sec audio files. I will be using 3 sec audio
dataf = pd.read_csv("/content/features_3_sec.csv")
dataf.head()
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# 1              2010.051501            65671.875673  ...   64.748276
# 2              2084.565132            75124.921716  ...   67.336563
# 3              1960.039988            82913.639269  ...   47.739452
# 4              1948.503884            60204.020268  ...   30.336359
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -3.241280   36.488243     0.722209   38.099152    -5.050335   33.618073
# 1    -6.055294   40.677654     0.159015   51.264091    -2.837699   97.030830
# 2    -1.768610   28.348579     2.378768   45.717648    -1.938424   53.050835
# 3    -3.841155   28.337118     1.218588   34.770935    -3.580352   50.836224
# 4     0.664582   45.880913     1.689446   51.363583    -3.392489   26.738789
#
#    mfcc20_mean  mfcc20_var  label
# 0    -0.243027   43.771767  blues
# 1     5.784063   59.943081  blues
# 2     2.517375   33.105122  blues
# 3     3.630866   32.023678  blues
# 4     0.536961   29.146694  blues
#
# [5 rows x 60 columns]

# %%
dataf.tail()
# Out:
#               filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 9985  rock.00099.5.wav   66149          0.349126         0.080515  0.050019
# 9986  rock.00099.6.wav   66149          0.372564         0.082626  0.057897
# 9987  rock.00099.7.wav   66149          0.347481         0.089019  0.052403
# 9988  rock.00099.8.wav   66149          0.387527         0.084815  0.066430
# 9989  rock.00099.9.wav   66149          0.369293         0.086759  0.050524
#
#        rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 9985  0.000097             1499.083005          164266.886443
# 9986  0.000088             1847.965128          281054.935973
# 9987  0.000701             1346.157659          662956.246325
# 9988  0.000320             2084.515327          203891.039161
# 9989  0.000067             1634.330126          411429.169769
#
#       spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 9985              1718.707215            85931.574523  ...   42.485981
# 9986              1906.468492            99727.037054  ...   32.415203
# 9987              1561.859087           138762.841945  ...   78.228149
# 9988              2018.366254            22860.992562  ...   28.323744
# 9989              1867.422378           119722.211518  ...   38.801735
#
#       mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 9985    -9.094270   38.326839    -4.246976   31.049839    -5.625813
# 9986   -12.375726   66.418587    -3.081278   54.414265   -11.960546
# 9987    -2.524483   21.778994     4.809936   25.980829     1.775686
# 9988    -5.363541   17.209942     6.462601   21.442928     2.354765
# 9989   -11.598399   58.983097    -0.178517   55.761299    -6.903252
#
#       mfcc19_var  mfcc20_mean  mfcc20_var  label
# 9985   48.804092     1.818823   38.966969   rock
# 9986   63.452255     0.428857   18.697033   rock
# 9987   48.582378    -0.299545   41.586990   rock
# 9988   24.843613     0.675824   12.787750   rock
# 9989   39.485901    -3.412534   31.727489   rock
#
# [5 rows x 60 columns]

# %%
dataf.shape
# Out:
# (9990, 60)

# %%
dataf.describe()
# Out:
#         length  chroma_stft_mean  chroma_stft_var     rms_mean       rms_var  \
# count   9990.0       9990.000000      9990.000000  9990.000000  9.990000e+03
# mean   66149.0          0.379534         0.084876     0.130859  2.676388e-03
# std        0.0          0.090466         0.009637     0.068545  3.585628e-03
# min    66149.0          0.107108         0.015345     0.000953  4.379535e-08
# 25%    66149.0          0.315698         0.079833     0.083782  6.145900e-04
# 50%    66149.0          0.384741         0.085108     0.121253  1.491318e-03
# 75%    66149.0          0.442443         0.091092     0.176328  3.130862e-03
# max    66149.0          0.749481         0.120964     0.442567  3.261522e-02
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# count             9990.000000           9.990000e+03              9990.000000
# mean              2199.219431           4.166727e+05              2241.385959
# std                751.860611           4.349644e+05               543.854449
# min                472.741636           8.118813e+02               499.162910
# 25%               1630.680158           1.231961e+05              1887.455790
# 50%               2208.628236           2.650692e+05              2230.575595
# 75%               2712.581884           5.624152e+05              2588.340505
# max               5432.534406           4.794119e+06              3708.147554
#
#        spectral_bandwidth_var  rolloff_mean  ...  mfcc16_mean   mfcc16_var  \
# count            9.990000e+03   9990.000000  ...  9990.000000  9990.000000
# mean             1.182711e+05   4566.076592  ...     1.448240    49.988755
# std              1.013505e+05   1642.065335  ...     5.735149    34.442816
# min              1.183520e+03    658.336276  ...   -26.850016     1.325786
# 25%              4.876553e+04   3378.311110  ...    -2.227478    29.584894
# 50%              8.996072e+04   4631.377892  ...     1.461623    41.702393
# 75%              1.585674e+05   5591.634521  ...     5.149752    59.274619
# max              1.235143e+06   9487.446477  ...    39.144405   683.932556
#
#        mfcc17_mean   mfcc17_var  mfcc18_mean   mfcc18_var  mfcc19_mean  \
# count  9990.000000  9990.000000  9990.000000  9990.000000  9990.000000
# mean     -4.198706    51.962753     0.739943    52.488851    -2.497306
# std       5.677379    36.400669     5.181313    38.177120     5.111799
# min     -27.809795     1.624544   -20.733809     3.437439   -27.448456
# 25%      -7.951722    29.863448    -2.516638    29.636197    -5.734123
# 50%      -4.443021    42.393583     0.733772    41.831377    -2.702366
# 75%      -0.726945    61.676964     3.888734    62.033906     0.514246
# max      34.048843   529.363342    36.970322   629.729797    31.365425
#
#         mfcc19_var  mfcc20_mean   mfcc20_var
# count  9990.000000  9990.000000  9990.000000
# mean     54.973829    -0.917584    57.322614
# std      41.585677     5.253243    46.444212
# min       3.065302   -35.640659     0.282131
# 25%      30.496412    -4.004475    30.011365
# 50%      43.435253    -1.030939    44.332155
# 75%      65.328602     2.216603    68.210421
# max    1143.230591    34.212101   910.473206
#
# [8 rows x 58 columns]

# %%
# removing filename column
dataf = dataf.drop(labels='filename',axis=1)

# %%
# looking into what i have
sample_audio = "/content/pop.00003.wav"
sample, sample_rate = librosa.load(sample_audio)


ipd.Audio(sample, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample, sample_rate = librosa.load(sample_audio, sr=16000)
print(len(sample),sample_rate)
# Out:
# 480003 16000

# %%
import matplotlib.pyplot as plt

# Plotting raw wave
plt.figure(figsize=(14, 6))
plt.plot(sample)
plt.title("/content/pop.00003.wav")
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
# Spectrogram, we have this in images folder
# way of representing signal loudness at diff freq
# also known as Sonographs
# when data is 3D then waterfall

stft = librosa.stft(sample)
stft_db = librosa.amplitude_to_db(abs(stft))
plt.figure(figsize=(14,6))
librosa.display.specshow(stft,sr=sample_rate,x_axis='time',y_axis='hz')
plt.colorbar()
# Out:
# <ipython-input-13-888a46d3efbf>:9: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   librosa.display.specshow(stft,sr=sample_rate,x_axis='time',y_axis='hz')

# %%
stft = librosa.stft(sample)
stft_db = librosa.amplitude_to_db(abs(stft))
plt.figure(figsize=(14,6))
librosa.display.specshow(stft_db,sr=sample_rate,x_axis='time',y_axis='hz')
plt.colorbar()

# %%
import matplotlib.pyplot as plt

# Plotting raw wave with spectral rolloff
plt.figure(figsize=(14, 6))
plt.plot(sample, alpha=0.3)  # Plot raw wave
plt.plot(spectral_rolloff, color='r')  # Plot spectral rolloff
plt.title('Waveform with Spectral Rolloff')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
# Zero crossing
plt.figure(figsize=(14,6))
plt.plot(sample[8000:12000])
plt.grid()

# %%
#count
zero_cross = librosa.zero_crossings(sample[8000:12000],pad=False)
print("Count {}".format(sum(zero_cross)))
# Out:
# Count 495

# %% [markdown]
# # Feature Extraction

# %%
class_list = dataf.iloc[:,-1]
convert = LabelEncoder()

# %%
y = convert.fit_transform(class_list)
y
# Out:
# array([0, 0, 0, ..., 9, 9, 9])

# %%
dataf.iloc[:,:-1]
# Out:
#       length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0      66149          0.335406         0.091048  0.130405  0.003521
# 1      66149          0.343065         0.086147  0.112699  0.001450
# 2      66149          0.346815         0.092243  0.132003  0.004620
# 3      66149          0.363639         0.086856  0.132565  0.002448
# 4      66149          0.335579         0.088129  0.143289  0.001701
# ...      ...               ...              ...       ...       ...
# 9985   66149          0.349126         0.080515  0.050019  0.000097
# 9986   66149          0.372564         0.082626  0.057897  0.000088
# 9987   66149          0.347481         0.089019  0.052403  0.000701
# 9988   66149          0.387527         0.084815  0.066430  0.000320
# 9989   66149          0.369293         0.086759  0.050524  0.000067
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                1773.065032          167541.630869              1972.744388
# 1                1816.693777           90525.690866              2010.051501
# 2                1788.539719          111407.437613              2084.565132
# 3                1655.289045          111952.284517              1960.039988
# 4                1630.656199           79667.267654              1948.503884
# ...                      ...                    ...                      ...
# 9985             1499.083005          164266.886443              1718.707215
# 9986             1847.965128          281054.935973              1906.468492
# 9987             1346.157659          662956.246325              1561.859087
# 9988             2084.515327          203891.039161              2018.366254
# 9989             1634.330126          411429.169769              1867.422378
#
#       spectral_bandwidth_var  rolloff_mean  ...  mfcc16_mean  mfcc16_var  \
# 0              117335.771563   3714.560359  ...    -2.853603   39.687145
# 1               65671.875673   3869.682242  ...     4.074709   64.748276
# 2               75124.921716   3997.639160  ...     4.806280   67.336563
# 3               82913.639269   3568.300218  ...    -1.359111   47.739452
# 4               60204.020268   3469.992864  ...     2.092937   30.336359
# ...                      ...           ...  ...          ...         ...
# 9985            85931.574523   3015.559458  ...     5.773784   42.485981
# 9986            99727.037054   3746.694524  ...     2.074155   32.415203
# 9987           138762.841945   2442.362154  ...    -1.005473   78.228149
# 9988            22860.992562   4313.266226  ...     4.123402   28.323744
# 9989           119722.211518   3462.042142  ...     1.342274   38.801735
#
#       mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0       -3.241280   36.488243     0.722209   38.099152    -5.050335
# 1       -6.055294   40.677654     0.159015   51.264091    -2.837699
# 2       -1.768610   28.348579     2.378768   45.717648    -1.938424
# 3       -3.841155   28.337118     1.218588   34.770935    -3.580352
# 4        0.664582   45.880913     1.689446   51.363583    -3.392489
# ...           ...         ...          ...         ...          ...
# 9985    -9.094270   38.326839    -4.246976   31.049839    -5.625813
# 9986   -12.375726   66.418587    -3.081278   54.414265   -11.960546
# 9987    -2.524483   21.778994     4.809936   25.980829     1.775686
# 9988    -5.363541   17.209942     6.462601   21.442928     2.354765
# 9989   -11.598399   58.983097    -0.178517   55.761299    -6.903252
#
#       mfcc19_var  mfcc20_mean  mfcc20_var
# 0      33.618073    -0.243027   43.771767
# 1      97.030830     5.784063   59.943081
# 2      53.050835     2.517375   33.105122
# 3      50.836224     3.630866   32.023678
# 4      26.738789     0.536961   29.146694
# ...          ...          ...         ...
# 9985   48.804092     1.818823   38.966969
# 9986   63.452255     0.428857   18.697033
# 9987   48.582378    -0.299545   41.586990
# 9988   24.843613     0.675824   12.787750
# 9989   39.485901    -3.412534   31.727489
#
# [9990 rows x 58 columns]

# %%
# scaling features
from sklearn.preprocessing import StandardScaler
fit = StandardScaler()
X = fit.fit_transform(np.array(dataf.iloc[:,:-1],dtype=float))

# %%
# dividing into training and test Data
X_train,x_test, Y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
print(len(Y_train),len(y_test))
# Out:
# 7992 1998

# %% [markdown]
# # Model Building

# %%
# Using CNN algorithm
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# building model

model = Sequential()

model.add(Dense(512,input_shape=(X_train.shape[1],),activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(256,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10,activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               30208
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 203338 (794.29 KB)
# Trainable params: 203338 (794.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics='accuracy')

# %%
earlystop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=10,min_delta=0.0001)
modelcheck = ModelCheckpoint('best_model.hdf5',monitor='val_accuracy',verbose=1,save_best_only=True,mode='max')

# %%
history = model.fit(X_train,Y_train, validation_data=(x_test,y_test), epochs=600, callbacks=[earlystop,modelcheck], batch_size=128)
# Out:
# Epoch 1/600
# 58/63 [==========================>...] - ETA: 0s - loss: 1.6230 - accuracy: 0.4224
# Epoch 1: val_accuracy improved from -inf to 0.63814, saving model to best_model.hdf5
# 63/63 [==============================] - 2s 15ms/step - loss: 1.5915 - accuracy: 0.4352 - val_loss: 1.0434 - val_accuracy: 0.6381
# Epoch 2/600
# 13/63 [=====>........................] - ETA: 0s - loss: 1.1681 - accuracy: 0.6070
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 60/63 [===========================>..] - ETA: 0s - loss: 1.0917 - accuracy: 0.6277
# Epoch 2: val_accuracy improved from 0.63814 to 0.73774, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 1.0893 - accuracy: 0.6280 - val_loss: 0.7772 - val_accuracy: 0.7377
# Epoch 3/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.8840 - accuracy: 0.6962
# Epoch 3: val_accuracy improved from 0.73774 to 0.76276, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8796 - accuracy: 0.6976 - val_loss: 0.6857 - val_accuracy: 0.7628
# Epoch 4/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.7733 - accuracy: 0.7384
# Epoch 4: val_accuracy improved from 0.76276 to 0.79429, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.7664 - accuracy: 0.7406 - val_loss: 0.5941 - val_accuracy: 0.7943
# Epoch 5/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.6711 - accuracy: 0.7746
# Epoch 5: val_accuracy improved from 0.79429 to 0.81682, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6720 - accuracy: 0.7754 - val_loss: 0.5424 - val_accuracy: 0.8168
# Epoch 6/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.6108 - accuracy: 0.7911
# Epoch 6: val_accuracy improved from 0.81682 to 0.81982, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6125 - accuracy: 0.7908 - val_loss: 0.5301 - val_accuracy: 0.8198
# Epoch 7/600
# 63/63 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.8209
# Epoch 7: val_accuracy improved from 0.81982 to 0.84585, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 12ms/step - loss: 0.5392 - accuracy: 0.8209 - val_loss: 0.4693 - val_accuracy: 0.8458
# Epoch 8/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.4734 - accuracy: 0.8386
# Epoch 8: val_accuracy improved from 0.84585 to 0.85235, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.4736 - accuracy: 0.8372 - val_loss: 0.4357 - val_accuracy: 0.8524
# Epoch 9/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.4375 - accuracy: 0.8518
# Epoch 9: val_accuracy improved from 0.85235 to 0.86486, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.4429 - accuracy: 0.8502 - val_loss: 0.4093 - val_accuracy: 0.8649
# Epoch 10/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.3877 - accuracy: 0.8734
# Epoch 10: val_accuracy improved from 0.86486 to 0.87237, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.3902 - accuracy: 0.8725 - val_loss: 0.3803 - val_accuracy: 0.8724
# Epoch 11/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.3538 - accuracy: 0.8841
# Epoch 11: val_accuracy improved from 0.87237 to 0.88338, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 16ms/step - loss: 0.3532 - accuracy: 0.8845 - val_loss: 0.3757 - val_accuracy: 0.8834
# Epoch 12/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.3190 - accuracy: 0.8945
# Epoch 12: val_accuracy did not improve from 0.88338
# 63/63 [==============================] - 1s 17ms/step - loss: 0.3181 - accuracy: 0.8953 - val_loss: 0.3610 - val_accuracy: 0.8754
# Epoch 13/600
# 62/63 [============================>.] - ETA: 0s - loss: 0.2914 - accuracy: 0.9069
# Epoch 13: val_accuracy improved from 0.88338 to 0.89039, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 18ms/step - loss: 0.2911 - accuracy: 0.9069 - val_loss: 0.3502 - val_accuracy: 0.8904
# Epoch 14/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.2667 - accuracy: 0.9086
# Epoch 14: val_accuracy improved from 0.89039 to 0.89439, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2659 - accuracy: 0.9094 - val_loss: 0.3255 - val_accuracy: 0.8944
# Epoch 15/600
# 58/63 [==========================>...] - ETA: 0s - loss: 0.2493 - accuracy: 0.9157
# Epoch 15: val_accuracy did not improve from 0.89439
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2455 - accuracy: 0.9169 - val_loss: 0.3188 - val_accuracy: 0.8939
# Epoch 16/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.2455 - accuracy: 0.9184
# Epoch 16: val_accuracy did not improve from 0.89439
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2455 - accuracy: 0.9185 - val_loss: 0.3287 - val_accuracy: 0.8929
# Epoch 17/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.2175 - accuracy: 0.9293
# Epoch 17: val_accuracy improved from 0.89439 to 0.89740, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2177 - accuracy: 0.9292 - val_loss: 0.3196 - val_accuracy: 0.8974
# Epoch 18/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.2054 - accuracy: 0.9339
# Epoch 18: val_accuracy improved from 0.89740 to 0.90791, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2058 - accuracy: 0.9332 - val_loss: 0.2915 - val_accuracy: 0.9079
# Epoch 19/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.1878 - accuracy: 0.9385
# Epoch 19: val_accuracy did not improve from 0.90791
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1880 - accuracy: 0.9383 - val_loss: 0.3072 - val_accuracy: 0.8984
# Epoch 20/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1720 - accuracy: 0.9421
# Epoch 20: val_accuracy did not improve from 0.90791
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1704 - accuracy: 0.9424 - val_loss: 0.2975 - val_accuracy: 0.9004
# Epoch 21/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1626 - accuracy: 0.9449
# Epoch 21: val_accuracy did not improve from 0.90791
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1646 - accuracy: 0.9446 - val_loss: 0.3190 - val_accuracy: 0.9069
# Epoch 22/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.1685 - accuracy: 0.9425
# Epoch 22: val_accuracy did not improve from 0.90791
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1694 - accuracy: 0.9418 - val_loss: 0.3310 - val_accuracy: 0.8984
# Epoch 23/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1561 - accuracy: 0.9498
# Epoch 23: val_accuracy improved from 0.90791 to 0.91191, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1575 - accuracy: 0.9497 - val_loss: 0.2830 - val_accuracy: 0.9119
# Epoch 24/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1338 - accuracy: 0.9562
# Epoch 24: val_accuracy did not improve from 0.91191
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1353 - accuracy: 0.9556 - val_loss: 0.3122 - val_accuracy: 0.9104
# Epoch 25/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1417 - accuracy: 0.9527
# Epoch 25: val_accuracy did not improve from 0.91191
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1411 - accuracy: 0.9531 - val_loss: 0.2981 - val_accuracy: 0.9079
# Epoch 26/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1242 - accuracy: 0.9598
# Epoch 26: val_accuracy improved from 0.91191 to 0.91391, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1244 - accuracy: 0.9595 - val_loss: 0.3147 - val_accuracy: 0.9139
# Epoch 27/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1256 - accuracy: 0.9611
# Epoch 27: val_accuracy did not improve from 0.91391
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1273 - accuracy: 0.9597 - val_loss: 0.2944 - val_accuracy: 0.9104
# Epoch 28/600
# 62/63 [============================>.] - ETA: 0s - loss: 0.1044 - accuracy: 0.9672
# Epoch 28: val_accuracy did not improve from 0.91391
# 63/63 [==============================] - 1s 15ms/step - loss: 0.1049 - accuracy: 0.9670 - val_loss: 0.3231 - val_accuracy: 0.9054
# Epoch 29/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9631
# Epoch 29: val_accuracy did not improve from 0.91391
# 63/63 [==============================] - 1s 17ms/step - loss: 0.1142 - accuracy: 0.9632 - val_loss: 0.3276 - val_accuracy: 0.9079
# Epoch 30/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.1105 - accuracy: 0.9599
# Epoch 30: val_accuracy improved from 0.91391 to 0.91642, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 17ms/step - loss: 0.1109 - accuracy: 0.9600 - val_loss: 0.2929 - val_accuracy: 0.9164
# Epoch 31/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.0991 - accuracy: 0.9667
# Epoch 31: val_accuracy did not improve from 0.91642
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1011 - accuracy: 0.9662 - val_loss: 0.3182 - val_accuracy: 0.9099
# Epoch 32/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1008 - accuracy: 0.9676
# Epoch 32: val_accuracy did not improve from 0.91642
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1008 - accuracy: 0.9675 - val_loss: 0.3193 - val_accuracy: 0.9164
# Epoch 33/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0963 - accuracy: 0.9681
# Epoch 33: val_accuracy improved from 0.91642 to 0.91892, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0967 - accuracy: 0.9680 - val_loss: 0.2764 - val_accuracy: 0.9189
# Epoch 34/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0899 - accuracy: 0.9712
# Epoch 34: val_accuracy did not improve from 0.91892
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0889 - accuracy: 0.9713 - val_loss: 0.3097 - val_accuracy: 0.9174
# Epoch 35/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0819 - accuracy: 0.9746
# Epoch 35: val_accuracy did not improve from 0.91892
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0819 - accuracy: 0.9745 - val_loss: 0.3005 - val_accuracy: 0.9104
# Epoch 36/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0840 - accuracy: 0.9721
# Epoch 36: val_accuracy did not improve from 0.91892
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0863 - accuracy: 0.9712 - val_loss: 0.2940 - val_accuracy: 0.9154
# Epoch 37/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0824 - accuracy: 0.9742
# Epoch 37: val_accuracy did not improve from 0.91892
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0833 - accuracy: 0.9738 - val_loss: 0.3323 - val_accuracy: 0.9104
# Epoch 38/600
# 63/63 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9722
# Epoch 38: val_accuracy did not improve from 0.91892
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0884 - accuracy: 0.9722 - val_loss: 0.2989 - val_accuracy: 0.9174
# Epoch 39/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.0801 - accuracy: 0.9731
# Epoch 39: val_accuracy did not improve from 0.91892
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0802 - accuracy: 0.9732 - val_loss: 0.2966 - val_accuracy: 0.9134
# Epoch 40/600
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0772 - accuracy: 0.9756
# Epoch 40: val_accuracy improved from 0.91892 to 0.92042, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0770 - accuracy: 0.9756 - val_loss: 0.3077 - val_accuracy: 0.9204
# Epoch 41/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0746 - accuracy: 0.9736
# Epoch 41: val_accuracy did not improve from 0.92042
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0745 - accuracy: 0.9735 - val_loss: 0.2989 - val_accuracy: 0.9179
# Epoch 42/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0678 - accuracy: 0.9773
# Epoch 42: val_accuracy did not improve from 0.92042
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0682 - accuracy: 0.9775 - val_loss: 0.3198 - val_accuracy: 0.9164
# Epoch 43/600
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0680 - accuracy: 0.9771
# Epoch 43: val_accuracy did not improve from 0.92042
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0708 - accuracy: 0.9762 - val_loss: 0.2916 - val_accuracy: 0.9194
# Epoch 43: early stopping

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
#from keras.models import load_model
#Model = load_model("./best_model.hdf5")

# %%
test_loss, test_accuracy = model.evaluate(x_test,y_test,batch_size=128)
print("Test loss : ",test_loss)
print("\nBest test accuracy : ",test_accuracy*100)
# Out:
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2916 - accuracy: 0.9194
# Test loss :  0.29161569476127625
#
# Best test accuracy :  91.94194078445435
